# %% [markdown]
# # query 2
#
# Get the top K words appearing in article titles
# e.g. K = 10,000

# %%
# using pyspark to handle parallelization.

#  setting up pyspark on RCC--
#    module load java
#    module load spark
#    set up python paths (todo, document this)

# %%
import pymysql

# todo clean up these imports
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext, SparkSession
from pyspark.sql.types import Row, StructType, StructField, IntegerType, StringType
import pyspark.sql.functions as f

import os
import time

# %%
start_time = time.time()

# %%
SUBMIT_ARGS = "--driver-class-path file:///home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar --jars file:///home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar pyspark-shell"
os.environ["PYSPARK_SUBMIT_ARGS"] = SUBMIT_ARGS

db_name = 'test_wos_cut_full'
url = "jdbc:mysql://localhost:3306/{}?useUnicode=true&useJDBCCompliantTimezoneShift=true&useLegacyDatetimeCode=false&serverTimezone=America/Chicago".format(db_name)  # mysql runs on port 3306

# %%
print('initializing spark')
# init spark
conf = SparkConf()
conf = (conf.setMaster('local[*]')
       .set('spark.driver.memory','120G')  # note: need to adjust this for current hardware
       .set("spark.jars", "/home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar"))        
'''
.set('spark.executor.memory','1G')  # 20
.set('spark.driver.memory','1G')   # 40
.set('spark.driver.maxResultSize','500M')  #.set('spark.storage.memoryFraction',0))  # this setting is now a legacy option
.set('spark.python.worker.reuse', 'false')
.set('spark.python.worker.memory','512m')
.set('spark.executor.cores','1'))
'''
sc = SparkContext(conf=conf)
#sc.addJar('home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar')  # temp
spark = SparkSession(sc)  # don't need this for vanilla RDDs

print(sc._conf.getAll())
# Out:
# initializing spark
# [('spark.repl.local.jars', 'file:///home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar'), ('spark.driver.memory', '120G'), ('spark.jars', '/home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar'), ('spark.executor.id', 'driver'), ('spark.app.name', 'pyspark-shell'), ('spark.app.id', 'local-1571102218930'), ('spark.driver.host', 'midway2-bigmem03.rcc.local'), ('spark.rdd.compress', 'True'), ('spark.driver.extraClassPath', 'file:///home/brendanchambers/my_resources/mysql-connector-java-8.0.16/mysql-connector-java-8.0.16.jar'), ('spark.serializer.objectStreamReset', '100'), ('spark.master', 'local[*]'), ('spark.submit.deployMode', 'client'), ('spark.ui.showConsoleProgress', 'true'), ('spark.driver.port', '44611')]

# %%
# todo

# read all titles using jdbc connector

# test read

tablename_ = 'publications'  # todo this needs to be corrected

sql = "(SELECT title FROM {}) AS t".format(tablename_)
print(sql)

start_time = time.time()
df = spark.read.format('jdbc').option("url", url)\
                              .option("dbtable", sql)\
                              .load().repartition(24).cache()  # todo set number of partitions
end_time = time.time()
print("dataframe loaded in {} s".format(end_time - start_time))

print(df.rdd.getNumPartitions())
# Out:
# (SELECT title FROM publications) AS t
# dataframe loaded in 2.903140068054199 s
# 24

# %%
# todo count most frequent tokens

K_words = 10000

# something like this--
topWordCounts = df.withColumn('word', f.explode(f.split(f.col('title'), ' ')))\
    .groupBy('word')\
    .count()\
    .sort('count', ascending=False)\
    .limit(K_words)\
    .collect()

print(topWordCounts)
# Out:
# [Row(word='OF', count=6006863), Row(word='AND', count=2718673), Row(word='IN', count=2651707), Row(word='-', count=1783850), Row(word='ON', count=841632), Row(word='THE', count=773007), Row(word='A', count=768672), Row(word='FOR', count=658962), Row(word='WITH', count=554537), Row(word='TO', count=532625), Row(word='BY', count=494162), Row(word='FROM', count=332001), Row(word='EFFECT', count=242110), Row(word='STUDY', count=188887), Row(word='EFFECTS', count=185392), Row(word='STUDIES', count=184495), Row(word='AN', count=172831), Row(word='NEW', count=147092), Row(word='AS', count=144222), Row(word='AT', count=142204), Row(word='SOME', count=141509), Row(word='ANALYSIS', count=113672), Row(word='DURING', count=108541), Row(word='SYNTHESIS', count=105864), Row(word='.2.', count=105722), Row(word='HUMAN', count=101288), Row(word='PROPERTIES', count=97909), Row(word='SYSTEM', count=97441), Row(word='STRUCTURE', count=97255), Row(word='BETWEEN', count=96942), Row(word='METHOD', count=93490), Row(word='.1.', count=91740), Row(word='RAT', count=88373), Row(word='TREATMENT', count=87482), Row(word='ACID', count=84345), Row(word='ACTIVITY', count=84242), Row(word='DETERMINATION', count=84038), Row(word='ITS', count=82325), Row(word='+', count=75679), Row(word='INFLUENCE', count=75287), Row(word='DEVELOPMENT', count=73609), Row(word='CELLS', count=71395), Row(word='USE', count=71003), Row(word='2', count=68424), Row(word='PATIENTS', count=67915), Row(word='AFTER', count=67888), Row(word='REACTION', count=67673), Row(word='USING', count=65391), Row(word='SYSTEMS', count=64846), Row(word='THEORY', count=64655), Row(word='REACTIONS', count=62464), Row(word='CHANGES', count=61592), Row(word='MODEL', count=60642), Row(word='RATS', count=60460), Row(word='THEIR', count=60155), Row(word='FORMATION', count=58293), Row(word='OR', count=56613), Row(word='CONTROL', count=56516), Row(word='ROLE', count=56296), Row(word='GROWTH', count=55717), Row(word='DISTRIBUTION', count=54120), Row(word='COMPARISON', count=53929), Row(word='EVALUATION', count=52921), Row(word='COMPOUNDS', count=52110), Row(word='BEHAVIOR', count=51609), Row(word='RESPONSE', count=50739), Row(word='EXPERIMENTAL', count=50691), Row(word='GERMAN', count=49440), Row(word='PLASMA', count=48881), Row(word='PRODUCTION', count=48286), Row(word='COMPLEXES', count=47706), Row(word='FUNCTION', count=47582), Row(word='DISEASE', count=46896), Row(word='.3.', count=45776), Row(word='APPLICATION', count=45676), Row(word='CHILDREN', count=45483), Row(word='NORMAL', count=45347), Row(word='DE', count=45150), Row(word='MECHANISM', count=44837), Row(word='CLINICAL', count=44629), Row(word='PROBLEMS', count=44148), Row(word='INTERACTION', count=43223), Row(word='REPORT', count=43049), Row(word='CORRECTION', count=42949), Row(word='METABOLISM', count=42784), Row(word='CASE', count=42739), Row(word='DERIVATIVES', count=42431), Row(word='MEASUREMENT', count=41392), Row(word='WATER', count=41333), Row(word='ACTION', count=41119), Row(word='INDUCED', count=40515), Row(word='UNDER', count=39299), Row(word='SERUM', count=39178), Row(word='SURFACE', count=38552), Row(word='TEMPERATURE', count=38364), Row(word='FRENCH', count=37855), Row(word='INVESTIGATION', count=37547), Row(word='PROTEIN', count=37462), Row(word='CHARACTERISTICS', count=37152), Row(word='MICE', count=37143), Row(word='CHEMICAL', count=36820), Row(word='CELL', count=36754), Row(word='ENERGY', count=36578), Row(word='ACUTE', count=36550), Row(word='CHARACTERIZATION', count=36388), Row(word='METHODS', count=36386), Row(word='ELECTRON', count=35909), Row(word='SOLUTIONS', count=35176), Row(word='MEASUREMENTS', count=35089), Row(word='DIFFERENT', count=34916), Row(word='LEVELS', count=34805), Row(word='LIVER', count=34566), Row(word='NUCLEAR', count=34367), Row(word='MAN', count=34130), Row(word='INTO', count=34113), Row(word='OBSERVATIONS', count=34101), Row(word='PREPARATION', count=34005), Row(word='EVIDENCE', count=33974), Row(word='TES ...

# %%
end_time = time.time()
# Out:
# elapsed (s): {}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c299ad268903> in <module>
#       1 end_time = time.time()
# ----> 2 print('elapsed (s): {}').format(end_time - start_time)
#
# AttributeError: 'NoneType' object has no attribute 'format'

# %%
print('elapsed (s): {}'.format(end_time - start_time))
# Out:
# elapsed (s): 40.33935356140137
